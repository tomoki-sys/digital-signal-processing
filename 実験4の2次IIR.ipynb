# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
T=1/8000
wc=500

# %%
def analize(Omega):

  Omega=Omega*1000*2*np.pi
  z=np.exp(1j*Omega*T)
  Gz=(wc**2)*((1+z**(-1))**2)/(((2/T)**2)*((1-z**(-1)))**2+(2/T)*np.sqrt(2)*(1-z**(-1))*(1+z**(-1))*wc+(wc*(1+z**(-1)))**2)
  y=abs(Gz)

  return y

# %%
x=np.arange(0.1,4.1,0.1)
y=np.vectorize(analize)(x)
print(y*0.5)
# Out:
# [2.67306792e-01 7.78699562e-02 3.47715107e-02 1.94498469e-02
#  1.23371326e-02 8.47032834e-03 6.13831631e-03 4.62486853e-03
#  3.58753131e-03 2.84586558e-03 2.29747987e-03 1.88076794e-03
#  1.55686212e-03 1.30025924e-03 1.09366379e-03 9.25011694e-04
#  7.85681114e-04 6.69378651e-04 5.71424458e-04 4.88281017e-04
#  4.17235099e-04 3.56178531e-04 3.03454209e-04 2.57746081e-04
#  2.17999341e-04 1.83361709e-04 1.53139709e-04 1.26765711e-04
#  1.03772860e-04 8.37758168e-05 6.64558493e-05 5.15492229e-05
#  3.88381111e-05 2.81434621e-05 1.93193993e-05 1.22488432e-05
#  6.84012145e-06 3.02439388e-06 7.53765873e-07 1.83076145e-36]

# %%
plt.plot(x,y*0.5)
plt.grid()
plt.show()

# %%
df=pd.DataFrame(y*0.5)
df.to_csv("実験4の2次IIR.csv",header=None,index=None)
